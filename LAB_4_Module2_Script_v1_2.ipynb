# %% [markdown]
# # IS 4487 Module 2 Script
#
# ## Agenda
#
# - Loading installed packages
# - Inspect data
# - Explore plot types
#
# Make sure you have downloaded tonight's script and data from Canvas.

# %% [markdown]
# ##Load Libraries
#
# In this class we will be using
# - Pandas
# - Scikitlearn
# - Matplotlib
#
# We can pull sample data from
# - statsmodels.api

# %%
import pandas as pd
import matplotlib as mpl
import sklearn as sl

# %% [markdown]
# ## Getting data into Pandas
#
# In this case we will load data from the statsmodels.org library
#
# See the Canvas assignments and lectures for a description of the Megatelco data
#
# **Note:** you will need to enter a code supplied by Google in the next step.

# %%
from google.colab import drive 
drive.mount('/content/gdrive', force_remount=True)

df = pd.read_csv (r'/content/Twitter_dataset.csv', encoding = 'latin1')

print (df)

# %%
#look at the top rows
df.head(1)
# Out:
#    Unnamed: 0                       _id                      created_at  \
# 0           0  6020fc7e9e1aa8e3e7ad0832  Mon Feb 08 04:29:58 +0000 2021
#
#              id               id_str  \
# 0  1.358630e+18  1358634152719839233
#
#                                             text display_text_range  \
# 0  @Rebe_Charizard ?????????????????????m(*_ _)m           [16, 45]
#
#                                               source  truncated  \
# 0  <a href="http://twitter.com/download/iphone" r...      False
#
#    in_reply_to_status_id  ...   matching_rules  retweeted_status  \
# 0           1.358630e+18  ...  [{'tag': None}]               NaN
#
#    extended_tweet extended_entities possibly_sensitive quoted_status_id  \
# 0             NaN               NaN                NaN              NaN
#
#   quoted_status_id_str quoted_status  quoted_status_permalink  scopes
# 0                  NaN           NaN                      NaN     NaN
#
# [1 rows x 39 columns]

# %%
#look at last rows
df.tail(10)

# %%
#get a summary of the dataset
df.describe()

# %%
#look at the datatypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9756 entries, 0 to 9755
# Data columns (total 39 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Unnamed: 0                 9756 non-null   int64
#  1   _id                        9756 non-null   object
#  2   created_at                 9756 non-null   object
#  3   id                         9756 non-null   float64
#  4   id_str                     9756 non-null   int64
#  5   text                       9756 non-null   object
#  6   display_text_range         3222 non-null   object
#  7   source                     9747 non-null   object
#  8   truncated                  9756 non-null   bool
#  9   in_reply_to_status_id      2863 non-null   float64
#  10  in_reply_to_status_id_str  2863 non-null   float64
#  11  in_reply_to_user_id        2985 non-null   float64
#  12  in_reply_to_user_id_str    2985 non-null   float64
# ...

# %%
df_clean = df

# %%
keep = ['text', 'source', 
        'in_reply_to_status_id', 'is_quote_status', 
        'quote_count', 'reply_count', 
        'retweet_count', 'favorite_count', 
        'favorited', 'retweeted']
        
df_clean1 = df_clean[keep]
df_clean1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9756 entries, 0 to 9755
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   text                   9756 non-null   object
#  1   source                 9747 non-null   object
#  2   in_reply_to_status_id  2863 non-null   float64
#  3   is_quote_status        9756 non-null   bool
#  4   quote_count            9756 non-null   int64
#  5   reply_count            9756 non-null   int64
#  6   retweet_count          9756 non-null   int64
#  7   favorite_count         9756 non-null   int64
#  8   favorited              9756 non-null   bool
#  9   retweeted              9756 non-null   bool
# dtypes: bool(3), float64(1), int64(4), object(2)
# memory usage: 562.2+ KB

# %%
hasM = df_clean1["text"].str.contains("M")

df_clean1[hasM].head()
# Out:
#                                                 text  \
# 1  RT @iiiRatcha: ????????????????????"??????????...
# 2  @kashDAI not you listening to cfm and m&amp;m ...
# 3  RT @_soniashenoy: M&amp;M says \nSsangyong dea...
# 4  RT @mmschocolate: This year?s #SuperBowlLV com...
# 5  RT @Tezhwa: ?????????????????????????????? ???...
#
#                                               source  in_reply_to_status_id  \
# 1  <a href="http://twitter.com/download/iphone" r...                    NaN
# 2  <a href="http://twitter.com/download/iphone" r...           1.358630e+18
# 3  <a href="https://mobile.twitter.com" rel="nofo...                    NaN
# 4  <a href="http://twitter.com/download/iphone" r...                    NaN
# 5  <a href="http://twitter.com/download/android" ...                    NaN
#
#    is_quote_status  quote_count  reply_count  retweet_count  favorite_count  \
# 1            False            0            0              0               0
# ...

# %%
key_words = [str('M&M'), "m&m", 'M & M', 'm & m','M and M','m and m']

prof = "M&amp;M?s"
profAlso = "m&amp;m"

df_mm_text = df_clean1[df_clean1['text'].str.contains(prof)]

df_mm_text.head()
# Out:
#                                                    text  \
# 707   RT @stats_feed: Each package of traditional mi...
# 3515                 M&amp;M Minis &gt; normal M&amp;Ms
# 4508  Hey M&amp;M company, my name is Karen but I?m ...
# 6226  RT @davechensky: Every time i watch an M&amp;M...
# 7108  RT @davechensky: Every time i watch an M&amp;M...
#
#                                                  source  \
# 707   <a href="https://mobile.twitter.com" rel="nofo...
# 3515  <a href="http://twitter.com/download/iphone" r...
# 4508  <a href="http://twitter.com/download/iphone" r...
# 6226  <a href="http://twitter.com/download/android" ...
# 7108  <a href="https://mobile.twitter.com" rel="nofo...
#
#       in_reply_to_status_id  is_quote_status  quote_count  reply_count  \
# 707                     NaN            False            0            0
# 3515                    NaN            False            0            0
# ...
